# %%
import pandas as pd

# %%
file_1 = ...
file_2 = pd.read_csv(...,index_col=None, header = 0)
file_3 = pd.read_csv(...,index_col=None, header = 0)
file_4 = pd.read_csv(...,index_col=None, header = 0)
#removed file names to avoid problems with original source


list_ = []
frame = pd.DataFrame()
list_.append(file_1)
list_.append(file_2)
list_.append(file_3)
list_.append(file_4)


frame = pd.concat(list_)

# %%
file_4 = frame.set_index('index')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/erisllangos/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'index'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
file_1.describe(include=['O'])
#file_24.describe(include=['O'])

# %%
file_1.head()

# %%
#Change from string to datetime

dt = pd.to_datetime(frame['localtime'])

frame['localtime']=dt

ht = pd.to_datetime(file_4['localtime'])

file_4['localtime']=ht

# %%
all_stocks = frame['symbol'].unique().tolist()
all_exch = file_4['exch'].unique().tolist()
fulldayAapl = frame.loc[frame['symbol'] == 'XOM']
fulldayAaplexch = fulldayAapl.loc[fulldayAapl['exch'] == 'ADF']

fulldayAaplexch.count()

# %%
halfdayStocks = file_4['symbol'].unique().tolist()
halfdayAapl = file_4.loc[file_4['symbol'] == 'AAPL']
halfdayAaplexch = halfdayAapl.loc[halfdayAapl['exch'] == 'NYSE']


halfdayAaplexch.count()

# %%
apple_prices = apple_table['price'].tolist()
#vz_prices = all_table['price'].tolist()
#all_prices = frame['price'].tolist()
#GE_prices = GE_table['price'].tolist()

# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

from pylab import rcParams
rcParams['figure.figsize'] = 20, 10


# the histogram of the data
plt.hist(all_prices, 5000, facecolor='green', alpha=0.75)

# add a 'best fit' line
#y = mlab.normpdf( bins, mu, sigma)
#l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('Size')
plt.ylabel('Frequency')
plt.title(r'$\mathrm{Histogram\ of\ Trade\ Prices}\ \ $')
plt.axis([0, 250, 0, 150000])
plt.grid(True)

plt.show()

# %%
apple_time = apple_table[['localtime','price']]
apple_time.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-6626d3dafd69> in <module>()
# ----> 1 vz_time = all_table[['localtime','price']]
#
# /Users/erisllangos/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /Users/erisllangos/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1539                     raise ValueError('Cannot index with multidimensional key')
#    1540
# -> 1541                 return self._getitem_iterable(key, axis=axis)
#    1542
#    1543             # nested tuple slicing
#
# ...

# %%
apple_time_1 = apple_time.sample(frac=.001)

# %%
apple_time.plot(x='localtime', y = 'price', color='orange')
plt.xlabel('Time')
plt.ylabel('Price')
plt.title(r'$\mathrm{TimeSeries\ of\ Apple}\ \ $')
plt.show()

# %%
apple_size = apple_table[['localtime','size']]

apple_size.plot(x='localtime', y = 'size', color='red')
plt.xlabel('Time')
plt.ylabel('Size')
plt.title(r'$\mathrm{TimeSeries\ of\ size\ of\ trades\ Day1\ GE}\ \ $')

plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('NASDAQ', 'EDGEX', 'ARCA')
y_pos = np.arange(len(objects))
performance = [a_t,a_edgex,a_arca]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Trades')
plt.title('AAPL by the Exchange')
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-368-86ca942a0348> in <module>()
#       7 performance = [a_t,a_edgex,a_arca]
#       8
# ----> 9 plt.bar(y_pos, performance, align='center', alpha=0.5)
#      10 plt.xticks(y_pos, objects)
#      11 plt.ylabel('Trades')
#
# /Users/erisllangos/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2702     try:
#    2703         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2704                      **kwargs)
#    2705     finally:
#    2706         ax._hold = washold
#
# /Users/erisllangos/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
# ...
